# %% [markdown]
# [Pruebas]

# %%
#print first hello world
print("Hello World")

#variables
a=5
b=4

#ops
suma = a+b
#result
print(f"Suma es {suma}")
# Out:
# Hello World
# Suma es 9

# %% [markdown]
# [DatosPersonales]

# %%
#variable declaration
name = "Sebastian Carvajal Motoya"
age = 24
height = 1.80
gender = 'M'
stillLives = True
telephone = "3004435831"
adress = "Cll49E #96B27"
siblingsNames = ["laura","maria","josue","julian","carla","juan","camilo"]
siblingsAges = {0:"21",1: "26",2: "29",3: "31",4:"34",5:"37",6:"40"}

# %% [markdown]
# [Impresiones]

# %%
#print of data before declareted
print("nombre: ",name)
print(f"edad: {age}")
print(f"altura: {height}")
print("genero: ", gender)
print("aun vive; ", stillLives)
print("telefono: ", telephone)
print("direccion: ",adress)
print("nombre hermanos: ",siblingsNames)
print("edad hermanos: ", siblingsAges)
print("------------------------------------------------------------------------------------")
print("Mi nombre es: ",name," tengo: ", age," años de edad\nmi genero es: ",gender," si se preguntan si sigo vivo pues: ",stillLives," \nmi telefono es: ", telephone, " por si se lo preguntan si quieren saber donde vivo, pues vivo en: ", adress, "\nlos nombres de mis hermanos son: ",siblingsNames,"\ny sus respectivas edades son: ",siblingsAges)
# Out:
# nombre:  Sebastian Carvajal Motoya
# edad: 24
# altura: 1.8
# genero:  M
# aun vive;  True
# telefono:  3004435831
# direccion:  Cll49E #96B27
# nombre hermanos:  ['laura', 'maria', 'josue', 'julian', 'carla', 'juan', 'camilo']
# edad hermanos:  {0: '21', 1: '26', 2: '29', 3: '31', 4: '34', 5: '37', 6: '40'}
# ------------------------------------------------------------------------------------
# Mi nombre es:  Sebastian Carvajal Motoya  tengo:  24  años de edad
# mi genero es:  M  si se preguntan si sigo vivo pues:  True
# mi telefono es:  3004435831  por si se lo preguntan si quieren saber donde vivo, pues vivo en:  Cll49E #96B27
# los nombres de mis hermanos son:  ['laura', 'maria', 'josue', 'julian', 'carla', 'juan', 'camilo']
# y sus respectivas edades son:  {0: '21', 1: '26', 2: '29', 3: '31', 4: '34', 5: '37', 6: '40'}
