# %% [markdown]
# [Pruebas]

# %%
#print first hello world
print("Hello World")

#variables
a=5
b=4

#ops
suma = a+b
#result
print(f"Suma es {suma}")
# Out:
# Hello World
# Suma es 9

# %% [markdown]
# [DatosPersonales]

# %%
#variable declaration
nombre = "Sebastian Carvajal Motoya"
edad = 24
estatura = 1.80
genero = m
aunVive = True
telefono = "3004435831"
direccion = "Cll49E #96B27"
nombreHermanos = ["laura","maria","josue","julian","carla","juan","camilo"]
edadHermanos = {1:"21",2: "26",3: "29",4 : "31",5:"34",6:"37",7:"40"}

# %% [markdown]
# [Expresiones]
